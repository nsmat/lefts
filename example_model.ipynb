# %%
import polars as pl

# %%
class Model:

    def __init__(self,*args, **kwargs):
        pass

    def train(self, train_df: pl.DataFrame):
        pass

    def predict(self, test_df: pl.DataFrame):
        pass

    def validate(self, validate_df: pl.DataFrame):
        pass

# %%
class LiftedModel:
    def __init__(self, model_constructor,  pomap):"
