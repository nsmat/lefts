# %%
# %load_ext autoreload
# %autoreload 2

# %%
from categorical_pomap import CategoricalPomap
from pomap.pomap import Pomap

# %%
import polars as pl

# %%
example_df = pl.from_dict(
    {'cat1': ['a', 'b'],
    'cat2': ['c', 'd',],
    'cat3': ['e', 'f']
    }
)

# %%
example_df
# Out:
# shape: (2, 3)
# ┌──────┬──────┬──────┐
# │ cat1 ┆ cat2 ┆ cat3 │
# │ ---  ┆ ---  ┆ ---  │
# │ str  ┆ str  ┆ str  │
# ╞══════╪══════╪══════╡
# │ a    ┆ c    ┆ e    │
# │ b    ┆ d    ┆ f    │
# └──────┴──────┴──────┘

# %%
pmap_cat1 = CategoricalPomap(column='cat1', labels=['a', 'b'])
pmap_cat2 = CategoricalPomap(column='cat2', labels=['c', 'd'])
pmap_cat3 = CategoricalPomap(column='cat3', labels=['e', 'f'])

# %%
pmap_prod_12 = pmap_cat1.product(pmap_cat2)

# %%
pmap_sum = pmap_cat3.sum(pmap_prod_12)

# %%
pmap_sum.name
# Out:
# "Categorical cat3: ['e', 'f'] + Categorical cat1: ['a', 'b'] x Categorical cat2: ['c', 'd']"

# %%
pmap_sum.labels
# Out:
# shape: (6, 3)
# ┌──────┬──────┬──────┐
# │ cat3 ┆ cat1 ┆ cat2 │
# │ ---  ┆ ---  ┆ ---  │
# │ str  ┆ str  ┆ str  │
# ╞══════╪══════╪══════╡
# │ e    ┆ null ┆ null │
# │ f    ┆ null ┆ null │
# │ null ┆ a    ┆ c    │
# │ null ┆ a    ┆ d    │
# │ null ┆ b    ┆ c    │
# │ null ┆ b    ┆ d    │
# └──────┴──────┴──────┘

# %%
pmap_prod_12._label_rows_as(example_df, {'cat1': 'a', 'cat2': 'b', 'cat3': None}, label_as='train')
# Out:
# shape: (2, 3)
# ┌──────┬──────┬──────┐
# │ cat1 ┆ cat2 ┆ cat3 │
# │ ---  ┆ ---  ┆ ---  │
# │ str  ┆ str  ┆ str  │
# ╞══════╪══════╪══════╡
# │ a    ┆ c    ┆ e    │
# │ b    ┆ d    ┆ f    │
# └──────┴──────┴──────┘
