# %%
# %load_ext autoreload
# %autoreload 2

# %%
from categorical_pomap import CategoricalPomap
import polars as pl

# %%
example_df = pl.from_dict(
    {'cat1': ['a', 'a', 'b', 'b'],
     'cat2': ['c', 'd', 'c', 'd'],
     'cat3': ['e', 'e', 'e', 'f'],
     }
)

# %%
example_df
# Out:
# shape: (4, 3)
# ┌──────┬──────┬──────┐
# │ cat1 ┆ cat2 ┆ cat3 │
# │ ---  ┆ ---  ┆ ---  │
# │ str  ┆ str  ┆ str  │
# ╞══════╪══════╪══════╡
# │ a    ┆ c    ┆ e    │
# │ a    ┆ d    ┆ e    │
# │ b    ┆ c    ┆ e    │
# │ b    ┆ d    ┆ f    │
# └──────┴──────┴──────┘

# %%
pmap_cat1 = CategoricalPomap(column='cat1', labels=['a', 'b'])
pmap_cat2 = CategoricalPomap(column='cat2', labels=['c', 'd'])
pmap_cat3 = CategoricalPomap(column='cat3', labels=['e', 'f'])

# %%
pmap_prod_12 = pmap_cat1.product(pmap_cat2)

# %%
pmap_sum = pmap_cat3.sum(pmap_prod_12)

# %%
pmap_sum.name
# Out:
# "Categorical cat3: ['e', 'f'] + Categorical cat1: ['a', 'b'] x Categorical cat2: ['c', 'd']"

# %%
pmap_sum.view_labels()
# Out:
# shape: (6, 3)
# ┌──────┬──────┬──────┐
# │ cat3 ┆ cat1 ┆ cat2 │
# │ ---  ┆ ---  ┆ ---  │
# │ str  ┆ str  ┆ str  │
# ╞══════╪══════╪══════╡
# │ e    ┆ null ┆ null │
# │ f    ┆ null ┆ null │
# │ null ┆ a    ┆ c    │
# │ null ┆ a    ┆ d    │
# │ null ┆ b    ┆ c    │
# │ null ┆ b    ┆ d    │
# └──────┴──────┴──────┘

# %%
pmap_prod_12.label_rows_as_train(
    example_df,
    label={'cat1': 'a', 'cat2': 'c', 'cat3': 'e'}
)
# Out:
# shape: (4, 3)
# ┌──────┬──────┬─────────────────────────────────┐
# │ cat1 ┆ cat2 ┆ train({'cat1': 'a', 'cat2': 'c… │
# │ ---  ┆ ---  ┆ ---                             │
# │ str  ┆ str  ┆ bool                            │
# ╞══════╪══════╪═════════════════════════════════╡
# │ a    ┆ c    ┆ false                           │
# │ a    ┆ d    ┆ false                           │
# │ b    ┆ c    ┆ false                           │
# │ b    ┆ d    ┆ false                           │
# └──────┴──────┴─────────────────────────────────┘

# %%
example_df
# Out:
# shape: (4, 2)
# ┌──────┬──────┐
# │ cat1 ┆ cat2 │
# │ ---  ┆ ---  │
# │ str  ┆ str  │
# ╞══════╪══════╡
# │ a    ┆ c    │
# │ a    ┆ d    │
# │ b    ┆ c    │
# │ b    ┆ d    │
# └──────┴──────┘
