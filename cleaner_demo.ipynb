# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from categorical_pomap import CategoricalPomap
import polars as pl

# %%
example_df = pl.from_dict(
    {'cat1': ['a', 'a', 'b', 'b'],
     'cat2': ['c', 'd', 'c', 'd'],
     'cat3': ['e', 'e', 'e', 'f'],
     }
)

# %%
example_df
# Out:
# shape: (4, 3)
# ┌──────┬──────┬──────┐
# │ cat1 ┆ cat2 ┆ cat3 │
# │ ---  ┆ ---  ┆ ---  │
# │ str  ┆ str  ┆ str  │
# ╞══════╪══════╪══════╡
# │ a    ┆ c    ┆ e    │
# │ a    ┆ d    ┆ e    │
# │ b    ┆ c    ┆ e    │
# │ b    ┆ d    ┆ f    │
# └──────┴──────┴──────┘

# %%
pmap_cat1 = CategoricalPomap(column='cat1', labels=['a', 'b'])
pmap_cat2 = CategoricalPomap(column='cat2', labels=['c', 'd'])
pmap_cat3 = CategoricalPomap(column='cat3', labels=['e', 'f'])

# %%
pmap_prod_12 = pmap_cat1.product(pmap_cat2)

# %%
pmap_sum = pmap_cat3.sum(pmap_prod_12)

# %%
pmap_sum.name
# Out:
# "Categorical cat3: ['e', 'f'] + Categorical cat1: ['a', 'b'] x Categorical cat2: ['c', 'd']"

# %%
pmap_sum.view_labels()
# Out:
# shape: (6, 3)
# ┌──────┬──────┬──────┐
# │ cat3 ┆ cat1 ┆ cat2 │
# │ ---  ┆ ---  ┆ ---  │
# │ str  ┆ str  ┆ str  │
# ╞══════╪══════╪══════╡
# │ e    ┆ null ┆ null │
# │ f    ┆ null ┆ null │
# │ null ┆ a    ┆ c    │
# │ null ┆ a    ┆ d    │
# │ null ┆ b    ┆ c    │
# │ null ┆ b    ┆ d    │
# └──────┴──────┴──────┘

# %%
pmap_prod_12.label_rows_as_train(
    example_df,
    label={'cat1': 'a', }
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_12238/2838062060.py in ?()
# ----> 1 pmap_prod_12.label_rows_as_train(
#       2     example_df,
#       3     label={'cat1': 'a', }
#       4 )
#
# ~/code/pomap/pomap.py in ?(self, df, label)
#      67     def label_rows_as_train(self, df: pl.DataFrame, label: dict) -> pl.DataFrame:
# ---> 68         df = self._label_rows_as(df, label, label_as='train')
#      69         return df
#
# ~/code/pomap/pomap.py in ?(self, df, label, label_as)
#     105                             'validate': self._validate_column_name,
#     106                             }[label_as]
#     107         column_name = column_name_func(label)
#     108
# --> 109         expr = self._label_expr(df, label, label_as)
#     110         return df.with_columns(expr.alias(column_name))
#
# <string> in ?(self, df, label, label_as)
#
# <string> in ?(.0)
# ---> 11 'Could not get source, probably due dynamically evaluated source code.'
#
# <string> in ?(self, df, label, label_as)
#
# ~/code/pomap/categorical_pomap.py in ?(self, label, df)
#      16     def train_label_expr(self, label, df: pl.DataFrame) -> pl.Expr:
# ---> 17         return pl.col(self._column) == label
#
# ~/code/pomap/.venv/lib/python3.11/site-packages/polars/expr/expr.py in ?(self, other)
#     171     def __eq__(self, other: IntoExpr) -> Expr:  # type: ignore[override]
#     172         warn_null_comparison(other)
# --> 173         other = parse_into_expression(other, str_as_lit=True)
#     174         return self._from_pyexpr(self._pyexpr.eq(other))
#
# ~/code/pomap/.venv/lib/python3.11/site-packages/polars/_utils/parse/expr.py in ?(input, str_as_lit, list_as_series, structify, dtype)
#      57         expr = F.col(input)
#      58     elif isinstance(input, list) and list_as_series:
#      59         expr = F.lit(pl.Series(input), dtype=dtype)
#      60     else:
# ---> 61         expr = F.lit(input, dtype=dtype)
#      62
#      63     return expr._pyexpr
#
# ~/code/pomap/.venv/lib/python3.11/site-packages/polars/functions/lit.py in ?(value, dtype, allow_object)
#     186             if dtype_name.startswith("timedelta64["):
#     187                 time_unit = dtype_name[len("timedelta64[") : -1]
#     188                 return lit(item).cast(Duration(time_unit))
#     189
# --> 190     except AttributeError:
#     191         item = value
#     192
#     193     return wrap_expr(plr.lit(item, allow_object, is_scalar=True))
#
# ~/code/pomap/.venv/lib/python3.11/site-packages/polars/dataframe/frame.py in ?(self, row, column)
#    1557                     "can only call `.item()` if the dataframe is of shape (1, 1),"
#    1558                     " or if explicit row/col values are provided;"
#    1559                     f" frame has shape {self.shape!r}"
#    1560                 )
# -> 1561                 raise ValueError(msg)
#    1562             return self._df.to_series(0).get_index(0)
#    1563
#    1564         elif row is None or column is None:
#
# ValueError: can only call `.item()` if the dataframe is of shape (1, 1), or if explicit row/col values are provided; frame has shape (4, 3)

# %%
example_df
# Out:
# shape: (4, 2)
# ┌──────┬──────┐
# │ cat1 ┆ cat2 │
# │ ---  ┆ ---  │
# │ str  ┆ str  │
# ╞══════╪══════╡
# │ a    ┆ c    │
# │ a    ┆ d    │
# │ b    ┆ c    │
# │ b    ┆ d    │
# └──────┴──────┘
